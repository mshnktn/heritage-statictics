# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/data-50-structure-6.csv.zip")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
heritage = df[["Объект","Регион","Категория историко-культурного значения","дата создания","Вид объекта"]] 
heritage
# Out:
#                                                    Объект  ... Вид объекта
# 0       Дом, в котором в 1917 г. находился Совет рабоч...  ...    Памятник
# 1                                      Дом Ф.Д. Маштакова  ...    Памятник
# 2                                               Дом жилой  ...    Памятник
# 3                            Памятник Александру Невскому  ...    Памятник
# 4       Здание городского торгового корпуса, где 14 де...  ...    Памятник
# ...                                                   ...  ...         ...
# 146840                                     Офицерский дом  ...    Памятник
# 146841                                       Штаб бригады  ...    Памятник
# 146842                             Дом начальника бригады  ...    Памятник
# 146843                                     Офицерский дом  ...    Памятник
# 146844  Дом культуры Национального исследовательского ...  ...    Памятник
#
# [146845 rows x 5 columns]

# %%
heritage[heritage["Регион"] == "Ярославская область"]
# Out:
#                                                    Объект  ... Вид объекта
# 3                            Памятник Александру Невскому  ...    Памятник
# 27                                              Дом жилой  ...    Памятник
# 29       Дом жилой Черновых, конец XVIII - начало XIX вв.  ...    Памятник
# 31                       Дом Илларионовых, конец XVIII в.  ...    Памятник
# 34                              Дом жилой, конец XVIII в.  ...    Памятник
# ...                                                   ...  ...         ...
# 146823             Церковь иконы Божией Матери "Знамение"  ...    Памятник
# 146824                       Ансамбль городских особняков  ...    Ансамбль
# 146825                               Особняк В.И.Соколова  ...    Памятник
# 146826  Особняк городского главы г. Романов-Борисоглеб...  ...    Памятник
# 146827                     Особняк Ванчаговых-Герасимовых  ...    Памятник
#
# [1523 rows x 5 columns]

# %%
heritage[(heritage["Регион"] == "Ярославская область") & (heritage["Объект"] == "Церковь") & (project["Категория историко-культурного значения"] == "Регионального значения")]
# Out:
#         Объект               Регион  ...      дата создания Вид объекта
# 15600  Церковь  Ярославская область  ...  1769 г.,  1783 г.    Памятник
# 16220  Церковь  Ярославская область  ...            1798 г.    Памятник
# 16716  Церковь  Ярославская область  ...     1760-1811 гг.     Памятник
#
# [3 rows x 5 columns]

# %%
yar = heritage[heritage["Регион"] == "Ярославская область"]
yar
# Out:
#                                                    Объект  ... Вид объекта
# 3                            Памятник Александру Невскому  ...    Памятник
# 27                                              Дом жилой  ...    Памятник
# 29       Дом жилой Черновых, конец XVIII - начало XIX вв.  ...    Памятник
# 31                       Дом Илларионовых, конец XVIII в.  ...    Памятник
# 34                              Дом жилой, конец XVIII в.  ...    Памятник
# ...                                                   ...  ...         ...
# 146823             Церковь иконы Божией Матери "Знамение"  ...    Памятник
# 146824                       Ансамбль городских особняков  ...    Ансамбль
# 146825                               Особняк В.И.Соколова  ...    Памятник
# 146826  Особняк городского главы г. Романов-Борисоглеб...  ...    Памятник
# 146827                     Особняк Ванчаговых-Герасимовых  ...    Памятник
#
# [1523 rows x 5 columns]

# %%
yar.describe(include = 'all')
# Out:
#         Объект               Регион  ...    дата создания Вид объекта
# count     1523                 1523  ...             1501        1523
# unique     952                    1  ...              796           3
# top     Селище  Ярославская область  ...  II тыс. до н.э.    Памятник
# freq       127                 1523  ...               46        1363
#
# [4 rows x 5 columns]

# %%
yar[(yar["дата создания"] >= "1501")]
# Out:
#                                                    Объект  ... Вид объекта
# 3                            Памятник Александру Невскому  ...    Памятник
# 27                                              Дом жилой  ...    Памятник
# 29       Дом жилой Черновых, конец XVIII - начало XIX вв.  ...    Памятник
# 31                       Дом Илларионовых, конец XVIII в.  ...    Памятник
# 34                              Дом жилой, конец XVIII в.  ...    Памятник
# ...                                                   ...  ...         ...
# 146823             Церковь иконы Божией Матери "Знамение"  ...    Памятник
# 146824                       Ансамбль городских особняков  ...    Ансамбль
# 146825                               Особняк В.И.Соколова  ...    Памятник
# 146826  Особняк городского главы г. Романов-Борисоглеб...  ...    Памятник
# 146827                     Особняк Ванчаговых-Герасимовых  ...    Памятник
#
# [1478 rows x 5 columns]

# %%
yar.sort_values(by = ["дата создания"], ascending=False, inplace=False, na_position='last', ignore_index=False)
# Out:
#                                                    Объект  ... Вид объекта
# 18313                                    Стоянка (селище)  ...    Памятник
# 145238                                   Стоянка (селище)  ...    Памятник
# 10042                                             Стоянка  ...    Памятник
# 23244             Стоянка "Уница", эпохи неолита и бронзы  ...    Памятник
# 21382                      Стоянка "Варос", эпоха неолита  ...    Памятник
# ...                                                   ...  ...         ...
# 37097                        Церковь Воздвижения, 1799 г.  ...    Памятник
# 38924   Дом, в котором жил Ушинский Константин Дмитрие...  ...    Памятник
# 40527   Церковь во имя преподобного Сергия Радонежског...  ...    Памятник
# 40528   Ограда со Святыми воротами, угловыми башнями и...  ...    Памятник
# 48293                       Дом Кузнецова В.Я., 1893 год   ...    Памятник
#
# [1523 rows x 5 columns]

# %%
yar['Объект'].value_counts()
# Out:
# Селище                                                 127
# Курганы                                                 57
# Дом жилой                                               40
# Селище 2                                                35
# Стоянка                                                 33
#                                                       ...
# Склады Крохоняткиных                                     1
# Усадьба Тюменевых-Переславцевых                          1
# Клещин                                                   1
# Училище женское                                          1
# Здание железнодорожного вокзала "Ярославль-Главный"      1
# Name: Объект, Length: 952, dtype: int64
